# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <b> Name: Agnes Ho Yin Yee </b> <br>
# Current Occupation: Field Engineer

# %% [markdown]
# <i> I am intested in data science because I would like to draw useful insights from available data. </i>

# %% [markdown]
# <h3> To perform math operation (addition) </h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# >  <h3>Block Quotes in Markdown Cells </h3>
#
# |Year| Month | Location | Username |
# |---|---|---|---|
# |2022| July | Malaysia | Ali |
# |2021| June | China | Lim Mei Ting |
# |2022| October | Indonesia| ~~Norhaliza~~ Siti Nurhaliza|
#
# ***
# <h4 span style = 'color:Blue'> Please refer to below instruction. </h4 /span>
#
# 1. Above table shows the details of personnel.
# 2. To get more details via survey.
# 3. A report should be prepared after the survey completed <span style= 'background:yellow'> with below content. </span>
#     - Executive Summary
#     - Main Content
#     - Way Forward
#     - Conclusion
#
#  For more details, refer to <a href="https://docs.python.org/3/"> Python Documentation </a>
#
#  ![people.PNG](attachment:people.PNG)
